# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,11,10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

# ax.plot(x,x,color="#650dbd")
# ax.plot(x,x,color="darkorange",lw=10,ls="-.")

# lines = ax.plot(x,x+1,color="purple",linewidth=5)
# lines[0].set_dashes([5,1,2])

ax.plot(x,x,color="purple",linewidth=1,marker=">")

ax.plot(x,x+1,color="red",linewidth=1,marker="o",markersize=10)

# %%
type(lines)
# Out:
# list

# %%
x
# Out:
# array([ 0.        ,  1.22222222,  2.44444444,  3.66666667,  4.88888889,
#         6.11111111,  7.33333333,  8.55555556,  9.77777778, 11.        ])
